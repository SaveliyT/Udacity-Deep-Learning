# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
    print (labels)
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
# [[  12]
#  [5240]
#  [3084]
#  [   6]
#  [ 195]
#  [  12]
#  [   2]
#  [   6]]
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'as', 'originated', 'term', 'of']
# [[ 195]
#  [   6]
#  [5240]
#  [3084]
#  [  12]
#  [3084]
#  [ 195]
#  [   2]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                     stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                           labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0

    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
                batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.045354
# Nearest to one: posture, bipedal, neill, nellie, racing, trinidad, dodi, welt,
# Nearest to first: dedicate, byrd, herein, manifestation, ibero, guarani, logos, keillor,
# Nearest to or: macrinus, singularity, calibers, mudslides, paucity, nymphs, regulars, hijackers,
# Nearest to he: fig, sub, deaths, stayed, pluralistic, pilgrims, theatre, criticizes,
# Nearest to new: backronym, rahilly, gases, equivocation, doorman, palatal, roca, rs,
# Nearest to can: emotion, lydia, romano, amarna, meditate, devanagari, opencyc, labatt,
# Nearest to not: owl, navy, tishri, montana, arson, care, blitter, mcmanus,
# Nearest to all: mikhail, gymnasium, propagating, transmitting, cartography, ulaanbaatar, idm, adlai,
# Nearest to of: johore, slavic, discipleship, embrace, alphabetically, uart, neutralize, outback,
# Nearest to had: antilles, overline, ils, lampoon, carabineros, transaction, officers, golems,
# Nearest to when: motorcyclists, ods, flocked, pohl, bendix, unchanged, removed, lifes,
# Nearest to this: banach, reduction, gentoo, ample, albuquerque, hj, scat, tait,
# Nearest to four: expecting, divination, univ, caliph, allegation, sidebar, hadassah, ligaments,
# Nearest to three: transylvanian, intelligencer, ene, surgeon, mnd, originators, inlaid, hengest,
# Nearest to has: sacramental, shutting, inside, saiyan, moustache, coastlines, nupedia, nashe,
# Nearest to also: decimals, genocidal, meeting, heterosexual, sl, zf, unsupported, guyana,
# Average loss at step 2000: 4.371204
# Average loss at step 4000: 3.880983
# Average loss at step 6000: 3.803946
# Average loss at step 8000: 3.754834
# Average loss at step 10000: 3.629616
# Nearest to one: two, three, seven, six, four, eight, nine, five,
# Nearest to first: memel, annie, herein, elegant, keillor, gus, averroes, monetarism,
# Nearest to or: and, regulars, singularity, rollout, for, agent, pitcher, glottis,
# Nearest to he: it, she, they, who, retain, there, log, bestiaries,
# Nearest to new: fleece, palatal, teenaged, supernaturalism, irritate, injection, backronym, whites,
# Nearest to can: would, will, could, may, are, amarna, cannot, must,
# Nearest to not: still, it, often, care, infielders, icrm, they, cohomology,
# Nearest to all: tertullian, certainty, effect, both, polynesia, replaces, pulsar, belt,
# Nearest to of: in, for, from, and, astra, with, photographer, punic,
# Nearest to had: has, antilles, have, was, is, were, overline, instituto,
# Nearest to when: penises, photonic, mm, five, convinces, diger, liberalised, disembarked,
# Nearest to this: which, it, the, there, that, bullshit, some, each,
# Nearest to four: three, eight, five, seven, six, nine, zero, two,
# Nearest to three: four, five, six, two, seven, eight, one, nine,
# Nearest to has: is, have, was, had, sacramental, neurath, shutting, susie,
# Nearest to also: which, always, logie, jeannie, sandwiched, still, often, there,
# Average loss at step 12000: 3.583383
# Average loss at step 14000: 3.605502
# Average loss at step 16000: 3.582255
# Average loss at step 18000: 3.571233
# Average loss at step 20000: 3.544340
# Nearest to one: seven, two, six, four, eight, three, nine, five,
# Nearest to first: second, memel, cherokee, next, herein, haunted, keillor, annie,
# Nearest to or: and, than, singularity, rocking, saterland, marcy, sloping, ontology,
# Nearest to he: she, it, who, they, there, marion, originally, retain,
# Nearest to new: sporadic, irritate, following, injection, madman, fleece, legislative, backronym,
# Nearest to can: would, will, may, could, cannot, must, should, to,
# Nearest to not: still, it, never, now, icrm, they, often, augmentation,
# Nearest to all: both, these, many, any, kelley, tertullian, bains, corsairs,
# Nearest to of: in, and, punic, throughout, labyrinth, during, for, at,
# Nearest to had: has, have, was, were, antilles, been, enjoyed, instituto,
# Nearest to when: if, because, lsch, could, photonic, where, liaison, after,
# Nearest to this: it, which, putting, the, any, some, delayed, godless,
# Nearest to four: six, five, eight, seven, three, two, nine, zero,
# Nearest to three: four, two, five, six, seven, eight, nine, zero,
# Nearest to has: had, have, was, is, since, groundwater, artillery, hora,
# Nearest to also: which, still, always, often, never, it, implements, sandwiched,
# Average loss at step 22000: 3.530629
# Average loss at step 24000: 3.445428
# Average loss at step 26000: 3.420253
# Average loss at step 28000: 3.475353
# Average loss at step 30000: 3.407051
# Nearest to one: six, seven, four, dispersed, two, ciboney, five, eight,
# Nearest to first: second, memel, annie, next, same, monetarism, keillor, release,
# Nearest to or: and, than, sacerdotal, ovarian, stanbul, sewage, strictest, lounge,
# Nearest to he: she, it, they, who, marion, there, later, never,
# Nearest to new: legislative, sporadic, injection, lusignan, stabbing, magnetopause, caer, fleece,
# Nearest to can: may, will, would, could, must, should, cannot, might,
# Nearest to not: still, we, they, it, visionary, now, icrm, there,
# Nearest to all: both, these, many, bains, various, authorities, any, each,
# Nearest to of: in, punic, astra, throughout, including, since, labyrinth, informing,
# Nearest to had: has, have, was, were, antilles, after, been, took,
# Nearest to when: if, because, after, where, although, while, though, was,
# Nearest to this: it, which, some, the, that, there, appian, putting,
# Nearest to four: six, five, seven, three, eight, two, zero, nine,
# Nearest to three: four, five, two, six, seven, eight, zero, nine,
# Nearest to has: had, have, is, was, groundwater, lajos, purifying, hora,
# Nearest to also: which, often, still, now, never, always, implements, kept,
# Average loss at step 32000: 3.419095
# Average loss at step 34000: 3.435741
# Average loss at step 36000: 3.363556
# Average loss at step 38000: 3.492073
# Average loss at step 40000: 3.445252
# Nearest to one: two, seven, six, eight, four, five, three, cheap,
# Nearest to first: second, last, next, confuses, during, before, memel, same,
# Nearest to or: and, but, lounge, than, strictest, grosbeak, sewage, revoke,
# Nearest to he: she, it, they, who, there, molson, marion, later,
# Nearest to new: legislative, sporadic, stabbing, interfacing, spiritualist, mountaineers, lusignan, caer,
# Nearest to can: may, will, would, could, must, should, cannot, might,
# Nearest to not: still, actually, it, usually, now, bretons, quite, often,
# Nearest to all: both, these, many, wahhabi, some, each, various, any,
# Nearest to of: punic, labyrinth, dimona, impoverishment, for, including, hazlitt, teschen,
# Nearest to had: has, have, was, were, enjoyed, kaiserliche, been, antilles,
# Nearest to when: if, after, while, because, before, where, although, though,
# Nearest to this: which, it, that, the, some, what, putting, soup,
# Nearest to four: five, six, three, eight, seven, zero, two, nine,
# Nearest to three: four, six, five, two, seven, eight, zero, nine,
# Nearest to has: had, have, was, is, since, invaluable, purifying, characterised,
# Nearest to also: often, still, which, now, always, never, implements, logie,
# Average loss at step 42000: 3.423838
# Average loss at step 44000: 3.273092
# Average loss at step 46000: 3.411904
# Average loss at step 48000: 3.431593
# Average loss at step 50000: 3.436838
# Nearest to one: seven, two, six, five, eight, four, three, nine,
# Nearest to first: second, last, next, memel, same, confuses, later, hominids,
# Nearest to or: and, but, than, offenbach, sewage, strictest, restless, tw,
# Nearest to he: she, it, they, who, there, we, molson, never,
# Nearest to new: legislative, stabbing, sporadic, lusignan, fleece, different, injection, steppenwolf,
# Nearest to can: may, would, will, could, must, should, might, cannot,
# Nearest to not: actually, still, quite, they, usually, better, icrm, bretons,
# Nearest to all: both, many, these, several, each, some, wahhabi, various,
# Nearest to of: labyrinth, in, punic, same, for, trainees, hazlitt, dimona,
# Nearest to had: has, have, was, were, having, since, been, kaiserliche,
# Nearest to when: if, after, before, because, while, though, where, by,
# Nearest to this: it, which, that, each, putting, minstrels, the, any,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to three: five, four, six, two, seven, eight, zero, nine,
# Nearest to has: had, have, was, is, since, having, purifying, psalter,
# Nearest to also: now, often, still, implements, which, never, always, comically,
# Average loss at step 52000: 3.449799
# Average loss at step 54000: 3.425164
# Average loss at step 56000: 3.402611
# Average loss at step 58000: 3.285296
# Average loss at step 60000: 3.382354
# Nearest to one: two, four, three, six, eight, five, seven, nine,
# Nearest to first: second, last, next, final, third, work, memel, during,
# Nearest to or: and, than, strictest, angular, rollout, sewage, any, but,
# Nearest to he: she, it, they, there, who, never, marion, tilted,
# Nearest to new: legislative, sporadic, lusignan, steppenwolf, specific, different, fourth, tabernacle,
# Nearest to can: could, may, will, would, should, must, might, cannot,
# Nearest to not: still, actually, almost, you, they, we, never, quite,
# Nearest to all: many, both, some, several, these, various, any, wahhabi,
# Nearest to of: including, labyrinth, in, punic, remixed, astra, automation, regained,
# Nearest to had: has, have, having, was, were, took, quartic, provider,
# Nearest to when: if, before, after, while, where, though, although, was,
# Nearest to this: it, which, the, that, another, appian, mulberry, ninety,
# Nearest to four: six, five, eight, three, seven, nine, two, one,
# Nearest to three: five, four, six, eight, two, seven, nine, one,
# Nearest to has: had, have, is, was, provides, since, although, unresolved,
# Nearest to also: often, who, which, now, still, never, implements, always,
# Average loss at step 62000: 3.439395
# Average loss at step 64000: 3.359474
# Average loss at step 66000: 3.343010
# Average loss at step 68000: 3.386540
# Average loss at step 70000: 3.374043
# Nearest to one: six, two, seven, eight, three, nine, four, five,
# Nearest to first: last, second, next, final, original, best, third, pendleton,
# Nearest to or: and, than, sewage, while, strictest, kalashnikov, transaction, bizarre,
# Nearest to he: she, it, they, there, marion, who, tilted, never,
# Nearest to new: legislative, lusignan, single, fourth, steppenwolf, igor, scheldt, tabernacle,
# Nearest to can: could, will, would, may, should, must, might, cannot,
# Nearest to not: still, actually, never, generally, they, nothing, better, now,
# Nearest to all: both, many, some, several, various, these, most, predecessors,
# Nearest to of: labyrinth, remixed, including, baserunner, astra, punic, drains, pertwee,
# Nearest to had: has, have, was, having, were, took, since, enjoyed,
# Nearest to when: if, while, before, after, where, although, though, because,
# Nearest to this: it, which, the, appian, another, he, each, there,
# Nearest to four: five, eight, seven, six, three, nine, two, zero,
# Nearest to three: four, five, eight, six, two, seven, nine, one,
# Nearest to has: had, have, was, is, since, although, whiteface, unresolved,
# Nearest to also: often, still, now, never, which, who, implements, always,
# Average loss at step 72000: 3.399587
# Average loss at step 74000: 3.388159
# Average loss at step 76000: 3.353497
# Average loss at step 78000: 3.239082
# Average loss at step 80000: 3.377615
# Nearest to one: two, seven, three, five, six, four, eight, nine,
# Nearest to first: last, second, next, original, best, mojito, final, third,
# Nearest to or: and, than, though, strictest, uncontrolled, sewage, grosbeak, sandinistas,
# Nearest to he: she, it, they, there, marion, who, tilted, hin,
# Nearest to new: legislative, lusignan, specific, single, modern, mountaineers, igor, fourth,
# Nearest to can: will, may, could, would, should, must, might, cannot,
# Nearest to not: actually, still, never, quite, almost, formally, usually, better,
# Nearest to all: both, many, some, wahhabi, every, jamaican, any, various,
# Nearest to of: and, in, including, loot, for, electronica, labyrinth, tabulate,
# Nearest to had: has, have, having, were, was, took, been, attempted,
# Nearest to when: if, while, before, although, after, though, where, because,
# Nearest to this: which, it, the, another, what, any, some, each,
# Nearest to four: five, six, seven, three, eight, nine, zero, two,
# Nearest to three: six, four, five, two, seven, eight, one, zero,
# Nearest to has: had, have, is, was, since, provides, includes, having,
# Nearest to also: often, still, now, which, sometimes, always, never, usually,
# Average loss at step 82000: 3.294790
# Average loss at step 84000: 3.338306
# Average loss at step 86000: 3.344515
# Average loss at step 88000: 3.320053
# Average loss at step 90000: 3.238964
# Nearest to one: two, seven, three, five, six, eight, four, nine,
# Nearest to first: last, second, next, third, best, original, entire, mojito,
# Nearest to or: and, than, strictest, seduction, sewage, amazonas, uncontrolled, anz,
# Nearest to he: she, it, they, there, marion, aslan, who, tilted,
# Nearest to new: lusignan, harrow, injection, igor, modern, fourth, tabernacle, mountaineers,
# Nearest to can: could, will, would, may, must, should, might, cannot,
# Nearest to not: actually, never, still, t, you, dah, usually, now,
# Nearest to all: both, many, various, several, some, wahhabi, these, any,
# Nearest to of: labyrinth, although, including, in, and, remixed, hazlitt, diplodocus,
# Nearest to had: has, have, was, having, took, enjoyed, were, attempted,
# Nearest to when: if, while, before, where, after, although, though, because,
# Nearest to this: it, which, another, some, what, each, he, mulberry,
# Nearest to four: seven, six, three, five, eight, nine, two, zero,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to has: had, have, is, was, since, having, provides, kaiserliche,
# Nearest to also: often, which, still, now, never, who, implements, sometimes,
# Average loss at step 92000: 2.734190
# Average loss at step 94000: 3.102479
# Average loss at step 96000: 3.067988
# Average loss at step 98000: 3.222778
# Average loss at step 100000: 3.279549
# Nearest to one: two, four, three, five, seven, six, dispersed, eight,
# Nearest to first: last, second, next, third, final, entire, pendleton, stereochemistry,
# Nearest to or: and, than, strictest, but, reuben, sewage, any, spaniel,
# Nearest to he: she, it, they, there, who, but, quickly, soon,
# Nearest to new: lusignan, modern, fourth, injection, igor, genetical, specific, bullying,
# Nearest to can: could, will, must, should, would, may, might, cannot,
# Nearest to not: actually, never, still, now, quite, usually, t, nor,
# Nearest to all: both, many, some, these, various, those, outside, several,
# Nearest to of: impoverishment, for, labyrinth, including, and, punic, regarding, concerning,
# Nearest to had: has, have, was, having, were, attempted, never, enjoyed,
# Nearest to when: if, before, though, where, although, while, after, because,
# Nearest to this: it, which, the, another, some, any, what, that,
# Nearest to four: seven, six, five, three, eight, nine, two, zero,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to has: had, have, is, was, since, although, broz, recently,
# Nearest to also: often, still, now, never, which, actually, sometimes, who,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
def generate_cbow_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for index in range(batch_size):
        data_list = list(buffer) 
        labels[index, 0] = data_list.pop(bag_window)
        batch[index] = data_list
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    return batch, labels
        
    
#print("data = {0}".format([index_to_word[each] for each in data[:16]]))
data_index, data_size, batch_size = 0, len(data), 5
for bag_window in [1, 2]:
    batch, labels = generate_cbow_batch(batch_size, bag_window)
#    print("bag_window = {0}".format(bag_window))
#    print("batch = {0}".format([[index_to_word[index] for index in each] for each in batch]))
#    print("labels = {0}\n".format([index_to_word[each] for each in labels.reshape(5)]))\
    
#    print(labels)
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(bag_window*10)] )
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(5)])
# Out:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse']
#     labels: ['originated', 'as', 'a', 'term', 'of']
#     batch: ['used', 'against', 'working', 'class', 'against', 'early', 'class', 'radicals', 'early', 'working', 'radicals', 'including', 'working', 'class', 'including', 'the', 'class', 'radicals', 'the', 'diggers']
#     labels: ['early', 'working', 'class', 'radicals', 'including']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    
    context_sum = tf.reduce_sum(embed, 1)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=context_sum,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_cbow_batch(batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.910899
# Nearest to three: hershey, chronica, blankets, thenceforth, ephesians, trombone, rockefeller, reymond,
# Nearest to he: symbolically, csx, ns, nz, manukau, mnemonics, muon, delayed,
# Nearest to for: amanullah, proclaim, parochial, diner, hm, ebro, debtor, ah,
# Nearest to years: dilapidated, mcluhan, fa, deceiver, parodied, christopher, graft, buses,
# Nearest to but: raions, epidemic, kyle, waldseem, dcc, giantess, forbidden, speculator,
# Nearest to during: wma, barroso, duomo, gavin, bbl, aetius, greens, malawi,
# Nearest to so: copeland, mamma, mania, summed, primarily, wanted, silicone, nearing,
# Nearest to five: larch, climber, refueling, nicolas, bawerk, evolutionist, unstoppable, patenting,
# Nearest to a: alto, horner, clockmaker, opel, blends, masoretes, seventeenth, avionics,
# Nearest to war: hajj, sidewise, mahjong, francis, graffiti, goes, risotto, letter,
# Nearest to may: prodigious, operating, oberon, allosaurus, aventine, haran, action, idaho,
# Nearest to state: radiance, brief, hourly, miltiades, efnet, depth, hauer, terribly,
# Nearest to two: bulky, murad, matra, depictions, shannon, glenda, franco, pocketing,
# Nearest to most: reintroducing, nest, stanzas, polarizing, es, melodrama, idi, hoyle,
# Nearest to over: lover, gulfs, institution, stanislav, vilas, apollinaris, favourite, forge,
# Nearest to his: east, renovations, assassin, calculating, cryptographer, judaica, conserve, com,
# Average loss at step 2000: 4.587674
# Average loss at step 4000: 3.939937
# Average loss at step 6000: 3.732547
# Average loss at step 8000: 3.535523
# Average loss at step 10000: 3.478079
# Nearest to three: seven, five, four, eight, six, two, zero, habibullah,
# Nearest to he: it, they, she, who, unequivocal, gaba, reformulated, franke,
# Nearest to for: depressive, of, torturing, mfm, rajput, dyson, ratu, wrought,
# Nearest to years: dilapidated, months, iadb, perish, christopher, time, year, reintroducing,
# Nearest to but: and, however, mussels, meritocracy, cistercians, microstates, although, rams,
# Nearest to during: in, at, wma, after, from, consensus, of, gavin,
# Nearest to so: pollutant, removal, spartans, schwa, saddened, less, lindo, fruit,
# Nearest to five: six, seven, four, eight, three, zero, nine, two,
# Nearest to a: the, another, any, an, tente, partnerships, matejko, each,
# Nearest to war: kilogram, relationship, francis, sidewise, thing, empire, shoal, chairperson,
# Nearest to may: can, would, will, could, should, must, might, to,
# Nearest to state: brief, avowed, depth, eisner, sidon, kaposi, colonies, council,
# Nearest to two: zero, five, six, quarter, three, overtook, premiership, quimby,
# Nearest to most: some, horror, droplets, notwithstanding, lifes, more, liege, giacomo,
# Nearest to over: lover, tricycle, bayou, stanislav, patch, encoding, rzburg, heinlein,
# Nearest to his: her, their, its, attica, the, hereditary, warfield, cryptologia,
# Average loss at step 12000: 3.489119
# Average loss at step 14000: 3.447386
# Average loss at step 16000: 3.438926
# Average loss at step 18000: 3.395072
# Average loss at step 20000: 3.213618
# Nearest to three: five, seven, eight, four, six, nine, mousse, privatised,
# Nearest to he: she, it, who, they, franke, harlan, irredentist, there,
# Nearest to for: hogshead, riley, dyson, aeon, while, shugart, if, after,
# Nearest to years: days, months, year, decades, dilapidated, mnp, iadb, barrows,
# Nearest to but: however, and, alte, rajendra, although, understandably, while, when,
# Nearest to during: in, before, through, since, after, over, until, while,
# Nearest to so: fruit, something, mansion, crevasses, import, spartans, oxycoccus, quantified,
# Nearest to five: seven, six, three, zero, four, eight, nine, dion,
# Nearest to a: the, another, any, each, an, every, byu, tribunals,
# Nearest to war: relaxing, kilogram, congested, cia, chairperson, stokes, amyl, mahjong,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to state: government, avowed, docherty, eisner, surat, accumulator, intercession, press,
# Nearest to two: aldehydes, rube, four, six, siona, nine, five, seven,
# Nearest to most: more, some, droplets, best, gall, horror, schleswig, jackal,
# Nearest to over: through, during, at, encoding, heinlein, lover, baguirmi, arbitrarily,
# Nearest to his: their, her, its, s, the, ghosting, lunch, our,
# Average loss at step 22000: 3.365597
# Average loss at step 24000: 3.298004
# Average loss at step 26000: 3.258893
# Average loss at step 28000: 3.285676
# Average loss at step 30000: 3.235801
# Nearest to three: four, five, six, eight, seven, two, zero, scud,
# Nearest to he: she, it, innovated, they, be, reluctance, franke, hopeful,
# Nearest to for: of, mfm, after, before, riley, glenda, ah, holmes,
# Nearest to years: days, year, months, decades, weeks, times, dilapidated, centimeters,
# Nearest to but: although, and, however, though, while, see, kenobi, lebedev,
# Nearest to during: before, until, after, in, since, throughout, through, despite,
# Nearest to so: sometimes, something, kombinate, propagate, mansion, advise, rdoba, handicaps,
# Nearest to five: six, three, seven, zero, eight, four, nine, two,
# Nearest to a: another, the, any, an, tente, brainiac, marquesas, every,
# Nearest to war: cia, render, relationship, relaxing, loading, treaty, safin, dieppe,
# Nearest to may: can, might, should, must, will, would, could, cannot,
# Nearest to state: government, avowed, substantial, cis, portion, council, cartagena, banks,
# Nearest to two: three, six, four, one, discretionary, terri, evaporate, five,
# Nearest to most: some, best, many, horror, schleswig, more, havoc, giacomo,
# Nearest to over: through, across, baguirmi, luthor, minaret, back, crocodiles, venezuela,
# Nearest to his: her, their, its, the, my, our, ilinden, human,
# Average loss at step 32000: 3.020094
# Average loss at step 34000: 3.210204
# Average loss at step 36000: 3.223698
# Average loss at step 38000: 3.165250
# Average loss at step 40000: 3.165300
# Nearest to three: six, seven, five, four, eight, two, affectionately, farthest,
# Nearest to he: she, it, they, this, nationals, crafted, crocodiles, passive,
# Nearest to for: lhasa, including, after, hibernation, without, braid, funerary, hogshead,
# Nearest to years: days, decades, months, year, times, centuries, seconds, weeks,
# Nearest to but: although, however, though, while, and, than, stopper, see,
# Nearest to during: in, after, throughout, through, before, despite, within, at,
# Nearest to so: too, sometimes, advise, heretofore, almaty, propagate, something, gaels,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to a: another, the, any, every, tente, byu, this, brainiac,
# Nearest to war: dieppe, relationship, safin, gegen, render, semitism, cia, completion,
# Nearest to may: might, can, will, could, should, would, must, cannot,
# Nearest to state: government, sidon, bahamas, fornax, seine, cosmologists, costly, xo,
# Nearest to two: five, three, zero, six, banshee, four, barra, micrometres,
# Nearest to most: more, less, best, some, pleasures, many, accused, horror,
# Nearest to over: throughout, around, across, sandpaper, through, at, off, about,
# Nearest to his: their, her, its, our, your, s, my, durrell,
# Average loss at step 42000: 3.212993
# Average loss at step 44000: 3.141481
# Average loss at step 46000: 3.145658
# Average loss at step 48000: 3.061957
# Average loss at step 50000: 3.056123
# Nearest to three: five, four, six, seven, eight, zero, two, tithes,
# Nearest to he: she, it, they, who, powell, surreptitiously, overflows, tenacious,
# Nearest to for: mfm, aor, braid, including, longships, diy, refrigerators, lhasa,
# Nearest to years: days, decades, months, year, hours, weeks, centuries, times,
# Nearest to but: though, although, and, however, jeopardy, yet, than, epistemology,
# Nearest to during: throughout, in, before, after, until, within, at, when,
# Nearest to so: thus, sometimes, then, steed, something, too, mansion, bajan,
# Nearest to five: four, three, six, seven, eight, zero, nine, two,
# Nearest to a: another, the, any, matejko, ris, marquesas, mutilated, outlining,
# Nearest to war: dieppe, completion, safin, semitism, cia, archer, championship, gegen,
# Nearest to may: should, can, might, must, could, would, will, cannot,
# Nearest to state: government, theresa, barn, misandry, constitution, supreme, component, city,
# Nearest to two: three, zero, four, five, scouring, jungles, mileage, alleviating,
# Nearest to most: many, less, more, havoc, best, horror, some, extremely,
# Nearest to over: across, through, around, off, geologic, monrovia, rinsing, versus,
# Nearest to his: her, their, its, our, s, the, your, my,
# Average loss at step 52000: 3.093793
# Average loss at step 54000: 3.092556
# Average loss at step 56000: 2.920558
# Average loss at step 58000: 3.017479
# Average loss at step 60000: 3.057500
# Nearest to three: five, seven, six, four, eight, zero, two, microelectronics,
# Nearest to he: she, it, they, who, bankrupt, powell, tenacious, firstnode,
# Nearest to for: after, against, mfm, before, braid, aor, bikes, shugart,
# Nearest to years: days, decades, months, hours, centuries, year, weeks, times,
# Nearest to but: and, although, however, than, though, while, see, serge,
# Nearest to during: throughout, after, before, in, since, within, until, despite,
# Nearest to so: fact, note, argued, assertion, alus, gaels, pentagon, bajan,
# Nearest to five: six, seven, eight, three, four, zero, nine, two,
# Nearest to a: another, any, the, every, an, no, mutilated, matejko,
# Nearest to war: dieppe, safin, semitism, undefeated, cia, chairperson, completion, period,
# Nearest to may: might, can, could, should, would, will, must, cannot,
# Nearest to state: government, elsie, supreme, blessing, incarnations, degree, xo, editions,
# Nearest to two: five, three, eight, six, four, several, nine, one,
# Nearest to most: some, many, best, more, less, jackal, havoc, giacomo,
# Nearest to over: through, across, throughout, around, off, about, before, despite,
# Nearest to his: her, their, its, s, your, our, the, my,
# Average loss at step 62000: 3.011503
# Average loss at step 64000: 2.917385
# Average loss at step 66000: 2.937713
# Average loss at step 68000: 2.962474
# Average loss at step 70000: 3.006921
# Nearest to three: five, six, seven, two, four, eight, veyron, rarities,
# Nearest to he: she, it, they, who, harlan, cosmologies, interrogating, irredentist,
# Nearest to for: after, mfm, of, kazantzakis, diy, against, nigerian, without,
# Nearest to years: days, decades, months, hours, centuries, year, weeks, minutes,
# Nearest to but: though, although, however, and, while, which, horizonte, serge,
# Nearest to during: throughout, in, after, at, before, despite, within, under,
# Nearest to so: fact, motherboards, note, kidneys, too, bajan, impressionists, assertion,
# Nearest to five: four, six, three, seven, eight, zero, two, mc,
# Nearest to a: the, another, every, any, matejko, byu, no, tente,
# Nearest to war: completion, undefeated, semitism, wars, safin, dieppe, cia, archer,
# Nearest to may: might, can, must, should, could, would, will, cannot,
# Nearest to state: government, viewer, settlement, disciplinary, elsie, republic, xo, memorial,
# Nearest to two: three, five, six, four, zero, seven, hitomaro, some,
# Nearest to most: many, some, more, less, particularly, jackal, best, giacomo,
# Nearest to over: across, through, within, throughout, about, during, around, at,
# Nearest to his: their, her, its, your, s, my, the, our,
# Average loss at step 72000: 2.945110
# Average loss at step 74000: 2.868251
# Average loss at step 76000: 3.001526
# Average loss at step 78000: 3.007753
# Average loss at step 80000: 2.842596
# Nearest to three: four, six, five, seven, eight, two, malayo, zero,
# Nearest to he: she, it, they, who, interrogating, sidney, perfecting, tenacious,
# Nearest to for: mfm, riley, shugart, earned, longships, samir, akhenaten, aor,
# Nearest to years: decades, days, months, centuries, weeks, year, hours, seconds,
# Nearest to but: although, though, however, and, see, because, or, while,
# Nearest to during: throughout, after, within, in, since, until, before, at,
# Nearest to so: too, sometimes, fact, bretwalda, nothing, motherboards, airmen, intercal,
# Nearest to five: four, six, seven, three, eight, zero, nine, antithetical,
# Nearest to a: another, any, the, every, tente, matejko, mondegreens, each,
# Nearest to war: wars, safin, dieppe, completion, cia, undefeated, semitism, ladies,
# Nearest to may: might, can, could, would, should, will, must, cannot,
# Nearest to state: government, elsie, charge, aspects, category, staff, republic, component,
# Nearest to two: three, four, six, one, zero, nine, eight, seven,
# Nearest to most: many, some, more, less, first, particularly, best, greatest,
# Nearest to over: throughout, across, within, around, during, off, encoding, lavinia,
# Nearest to his: her, their, its, your, my, the, our, s,
# Average loss at step 82000: 2.936267
# Average loss at step 84000: 2.894683
# Average loss at step 86000: 2.921325
# Average loss at step 88000: 2.942738
# Average loss at step 90000: 2.828962
# Nearest to three: five, seven, four, six, eight, two, zero, helium,
# Nearest to he: she, it, they, interrogating, aqua, elagabalus, roosevelt, greenspan,
# Nearest to for: after, meanwhile, effendi, hittite, inlaid, colossus, mfm, escher,
# Nearest to years: decades, days, months, centuries, weeks, hours, seconds, year,
# Nearest to but: however, although, though, than, because, intercepts, combats, lured,
# Nearest to during: throughout, after, in, before, within, post, until, at,
# Nearest to so: sometimes, too, almaty, once, motherboards, intercal, fact, deification,
# Nearest to five: six, four, seven, eight, three, zero, two, hundred,
# Nearest to a: another, the, every, any, this, tente, mondegreens, impeller,
# Nearest to war: wars, gegen, completion, semitism, safin, undefeated, championship, corsican,
# Nearest to may: can, might, should, must, will, would, could, cannot,
# Nearest to state: republic, government, herbivorous, nami, monopoly, constitution, refreshed, mosander,
# Nearest to two: four, three, seven, six, five, one, nine, eight,
# Nearest to most: some, more, many, less, particularly, best, especially, shelves,
# Nearest to over: across, around, within, throughout, during, off, about, encoding,
# Nearest to his: their, her, its, my, your, our, the, whose,
# Average loss at step 92000: 2.898028
# Average loss at step 94000: 2.888865
# Average loss at step 96000: 2.710646
# Average loss at step 98000: 2.455069
# Average loss at step 100000: 2.707677
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to he: she, it, they, interrogating, who, hume, gaunt, amplifying,
# Nearest to for: without, shugart, earned, behind, inlaid, after, braid, rhetorical,
# Nearest to years: decades, months, days, hours, centuries, weeks, year, minutes,
# Nearest to but: although, however, and, though, than, while, minutemen, until,
# Nearest to during: throughout, in, after, despite, until, since, at, over,
# Nearest to so: too, motherboards, sometimes, bajan, what, feet, believe, mimic,
# Nearest to five: six, seven, four, three, eight, zero, nine, two,
# Nearest to a: another, the, ris, something, every, mondegreens, tente, marquesas,
# Nearest to war: wars, undefeated, safin, dieppe, championship, completion, eretz, olsen,
# Nearest to may: might, must, should, would, can, will, could, cannot,
# Nearest to state: government, laissez, republic, maryland, city, mets, dewey, huron,
# Nearest to two: three, four, five, seven, six, zero, licensee, eight,
# Nearest to most: more, less, best, many, particularly, greatest, some, especially,
# Nearest to over: throughout, across, about, off, around, during, nearly, margin,
# Nearest to his: her, their, its, my, s, your, the, our,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
